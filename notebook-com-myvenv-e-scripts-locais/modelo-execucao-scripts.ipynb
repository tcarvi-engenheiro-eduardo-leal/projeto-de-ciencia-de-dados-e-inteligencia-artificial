# %% [markdown]
# ### Apenas para execução de scripts copiados da documentação markdown.
# - Se quiser ter novamente ter este arquivo com campos vazios, execute `git reset --hard origin/main`. Para o caso do seu repositório usar branch master, use comando com nome `master` e não com `main`.
